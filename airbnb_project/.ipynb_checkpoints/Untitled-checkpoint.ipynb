# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\vasudha.tanniru\\Documents\\GitHub\\data_projects\\airbnb_project'

# %%
df = pd.read_csv("full.csv")
df.head()
# Out:
#      id                        listing_url  \
# 0  2595  https://www.airbnb.com/rooms/2595
# 1  5121  https://www.airbnb.com/rooms/5121
# 2  6848  https://www.airbnb.com/rooms/6848
# 3  6990  https://www.airbnb.com/rooms/6990
# 4  6872  https://www.airbnb.com/rooms/6872
#
#                                                 name  \
# 0  Rental unit in New York · ★4.68 · Studio · 1 b...
# 1  Rental unit in Brooklyn · ★4.52 · 1 bedroom · ...
# 2  Rental unit in Brooklyn · ★4.58 · 2 bedrooms ·...
# 3  Rental unit in New York · ★4.88 · 1 bedroom · ...
# 4  Condo in New York · 1 bedroom · 1 bed · 1 shar...
#
#                                          picture_url  latitude  longitude  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...  40.75356  -73.98559
# 1  https://a0.muscache.com/pictures/2090980c-b68e...  40.68535  -73.95512
# 2  https://a0.muscache.com/pictures/e4f031a7-f146...  40.70935  -73.95342
# 3  https://a0.muscache.com/pictures/be6cd5b3-9295...  40.78778  -73.94759
# 4  https://a0.muscache.com/pictures/miso/Hosting-...  40.80107  -73.94255
#
#                  property_type        room_type  accommodates bathrooms_text  \
# 0           Entire rental unit  Entire home/apt             1         1 bath
# 1  Private room in rental unit     Private room             2            NaN
# 2           Entire rental unit  Entire home/apt             3         1 bath
# 3  Private room in rental unit     Private room             1  1 shared bath
# 4        Private room in condo     Private room             1  1 shared bath
#
#    bedrooms  beds                                          amenities    price  \
# 0       NaN   1.0  ["Long term stays allowed", "Cooking basics", ...  $240.00
# 1       1.0   1.0  ["Air conditioning", "Wifi", "Kitchen", "Heati...   $66.00
# 2       2.0   1.0  ["Cooking basics", "Microwave", "Extra pillows...   $81.00
# 3       1.0   1.0  ["Hair dryer", "Air conditioning", "Fire extin...   $70.00
# 4       1.0   1.0  ["Fire extinguisher", "Long term stays allowed...   $65.00
#
#    minimum_nights  maximum_nights  availability_30  availability_365  \
# 0              30            1125                4               339
# 1              30             730               30                88
# 2              30             730                0               142
# 3              30             365                0                93
# 4              30             180               24               359
#
#   neighbourhood_group       neighbourhood
# 0           Manhattan             Midtown
# 1            Brooklyn  Bedford-Stuyvesant
# 2            Brooklyn        Williamsburg
# 3           Manhattan         East Harlem
# 4           Manhattan         East Harlem

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39627 entries, 0 to 39626
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   39627 non-null  int64
#  1   listing_url          39627 non-null  object
#  2   name                 39627 non-null  object
#  3   picture_url          39627 non-null  object
#  4   latitude             39627 non-null  float64
#  5   longitude            39627 non-null  float64
#  6   property_type        39627 non-null  object
#  7   room_type            39627 non-null  object
#  8   accommodates         39627 non-null  int64
#  9   bathrooms_text       39590 non-null  object
#  10  bedrooms             36218 non-null  float64
#  11  beds                 38972 non-null  float64
#  12  amenities            39627 non-null  object
#  13  price                39627 non-null  object
#  14  minimum_nights       39627 non-null  int64
#  15  maximum_nights       39627 non-null  int64
#  16  availability_30      39627 non-null  int64
#  17  availability_365     39627 non-null  int64
#  18  neighbourhood_group  39627 non-null  object
#  19  neighbourhood        39627 non-null  object
# dtypes: float64(4), int64(6), object(10)
# memory usage: 6.0+ MB

# %%
df.isnull().sum()
# Out:
# id                        0
# listing_url               0
# name                      0
# picture_url               0
# latitude                  0
# longitude                 0
# property_type             0
# room_type                 0
# accommodates              0
# bathrooms_text           37
# bedrooms               3409
# beds                    655
# amenities                 0
# price                     0
# minimum_nights            0
# maximum_nights            0
# availability_30           0
# availability_365          0
# neighbourhood_group       0
# neighbourhood             0
# dtype: int64

# %%
df['bathrooms_text'] = df['bathrooms_text'].fillna("Unknown")

# %%
df.head()
# Out:
#      id                        listing_url  \
# 0  2595  https://www.airbnb.com/rooms/2595
# 1  5121  https://www.airbnb.com/rooms/5121
# 2  6848  https://www.airbnb.com/rooms/6848
# 3  6990  https://www.airbnb.com/rooms/6990
# 4  6872  https://www.airbnb.com/rooms/6872
#
#                                                 name  \
# 0  Rental unit in New York · ★4.68 · Studio · 1 b...
# 1  Rental unit in Brooklyn · ★4.52 · 1 bedroom · ...
# 2  Rental unit in Brooklyn · ★4.58 · 2 bedrooms ·...
# 3  Rental unit in New York · ★4.88 · 1 bedroom · ...
# 4  Condo in New York · 1 bedroom · 1 bed · 1 shar...
#
#                                          picture_url  latitude  longitude  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...  40.75356  -73.98559
# 1  https://a0.muscache.com/pictures/2090980c-b68e...  40.68535  -73.95512
# 2  https://a0.muscache.com/pictures/e4f031a7-f146...  40.70935  -73.95342
# 3  https://a0.muscache.com/pictures/be6cd5b3-9295...  40.78778  -73.94759
# 4  https://a0.muscache.com/pictures/miso/Hosting-...  40.80107  -73.94255
#
#                  property_type        room_type  accommodates bathrooms_text  \
# 0           Entire rental unit  Entire home/apt             1         1 bath
# 1  Private room in rental unit     Private room             2        Unknown
# 2           Entire rental unit  Entire home/apt             3         1 bath
# 3  Private room in rental unit     Private room             1  1 shared bath
# 4        Private room in condo     Private room             1  1 shared bath
#
#    bedrooms  beds                                          amenities    price  \
# 0       NaN   1.0  ["Long term stays allowed", "Cooking basics", ...  $240.00
# 1       1.0   1.0  ["Air conditioning", "Wifi", "Kitchen", "Heati...   $66.00
# 2       2.0   1.0  ["Cooking basics", "Microwave", "Extra pillows...   $81.00
# 3       1.0   1.0  ["Hair dryer", "Air conditioning", "Fire extin...   $70.00
# 4       1.0   1.0  ["Fire extinguisher", "Long term stays allowed...   $65.00
#
#    minimum_nights  maximum_nights  availability_30  availability_365  \
# 0              30            1125                4               339
# 1              30             730               30                88
# 2              30             730                0               142
# 3              30             365                0                93
# 4              30             180               24               359
#
#   neighbourhood_group       neighbourhood
# 0           Manhattan             Midtown
# 1            Brooklyn  Bedford-Stuyvesant
# 2            Brooklyn        Williamsburg
# 3           Manhattan         East Harlem
# 4           Manhattan         East Harlem

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39627 entries, 0 to 39626
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   39627 non-null  int64
#  1   listing_url          39627 non-null  object
#  2   name                 39627 non-null  object
#  3   picture_url          39627 non-null  object
#  4   latitude             39627 non-null  float64
#  5   longitude            39627 non-null  float64
#  6   property_type        39627 non-null  object
#  7   room_type            39627 non-null  object
#  8   accommodates         39627 non-null  int64
#  9   bathrooms_text       39627 non-null  object
#  10  bedrooms             36218 non-null  float64
#  11  beds                 38972 non-null  float64
#  12  amenities            39627 non-null  object
#  13  price                39627 non-null  object
#  14  minimum_nights       39627 non-null  int64
#  15  maximum_nights       39627 non-null  int64
#  16  availability_30      39627 non-null  int64
#  17  availability_365     39627 non-null  int64
#  18  neighbourhood_group  39627 non-null  object
#  19  neighbourhood        39627 non-null  object
# dtypes: float64(4), int64(6), object(10)
# memory usage: 6.0+ MB

# %%
print(df['bedrooms'].median())
# Out:
# 1.0

# %%
df['bedrooms'] = df['bedrooms'].fillna(df['bedrooms'].median())

# %%
df.isnull().sum()
# Out:
# id                       0
# listing_url              0
# name                     0
# picture_url              0
# latitude                 0
# longitude                0
# property_type            0
# room_type                0
# accommodates             0
# bathrooms_text           0
# bedrooms                 0
# beds                   655
# amenities                0
# price                    0
# minimum_nights           0
# maximum_nights           0
# availability_30          0
# availability_365         0
# neighbourhood_group      0
# neighbourhood            0
# dtype: int64

# %%
print(df['beds'].median())
# Out:
# 1.0

# %%
df['beds'] = df['beds'].fillna(df['beds'].median())

# %%
df.head()
# Out:
#      id                        listing_url  \
# 0  2595  https://www.airbnb.com/rooms/2595
# 1  5121  https://www.airbnb.com/rooms/5121
# 2  6848  https://www.airbnb.com/rooms/6848
# 3  6990  https://www.airbnb.com/rooms/6990
# 4  6872  https://www.airbnb.com/rooms/6872
#
#                                                 name  \
# 0  Rental unit in New York · ★4.68 · Studio · 1 b...
# 1  Rental unit in Brooklyn · ★4.52 · 1 bedroom · ...
# 2  Rental unit in Brooklyn · ★4.58 · 2 bedrooms ·...
# 3  Rental unit in New York · ★4.88 · 1 bedroom · ...
# 4  Condo in New York · 1 bedroom · 1 bed · 1 shar...
#
#                                          picture_url  latitude  longitude  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...  40.75356  -73.98559
# 1  https://a0.muscache.com/pictures/2090980c-b68e...  40.68535  -73.95512
# 2  https://a0.muscache.com/pictures/e4f031a7-f146...  40.70935  -73.95342
# 3  https://a0.muscache.com/pictures/be6cd5b3-9295...  40.78778  -73.94759
# 4  https://a0.muscache.com/pictures/miso/Hosting-...  40.80107  -73.94255
#
#                  property_type        room_type  accommodates bathrooms_text  \
# 0           Entire rental unit  Entire home/apt             1         1 bath
# 1  Private room in rental unit     Private room             2        Unknown
# 2           Entire rental unit  Entire home/apt             3         1 bath
# 3  Private room in rental unit     Private room             1  1 shared bath
# 4        Private room in condo     Private room             1  1 shared bath
#
#    bedrooms  beds                                          amenities    price  \
# 0       1.0   1.0  ["Long term stays allowed", "Cooking basics", ...  $240.00
# 1       1.0   1.0  ["Air conditioning", "Wifi", "Kitchen", "Heati...   $66.00
# 2       2.0   1.0  ["Cooking basics", "Microwave", "Extra pillows...   $81.00
# 3       1.0   1.0  ["Hair dryer", "Air conditioning", "Fire extin...   $70.00
# 4       1.0   1.0  ["Fire extinguisher", "Long term stays allowed...   $65.00
#
#    minimum_nights  maximum_nights  availability_30  availability_365  \
# 0              30            1125                4               339
# 1              30             730               30                88
# 2              30             730                0               142
# 3              30             365                0                93
# 4              30             180               24               359
#
#   neighbourhood_group       neighbourhood
# 0           Manhattan             Midtown
# 1            Brooklyn  Bedford-Stuyvesant
# 2            Brooklyn        Williamsburg
# 3           Manhattan         East Harlem
# 4           Manhattan         East Harlem

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['price_per_bedroom'] = df['price']/df['bedrooms']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df['price_per_bedroom'] = df['price']/df['bedrooms']
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arraylike.py:210, in OpsMixin.__truediv__(self, other)
#     208 @unpack_zerodim_and_defer("__truediv__")
#     209 def __truediv__(self, other):
# --> 210     return self._arith_method(other, operator.truediv)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:6135, in Series._arith_method(self, other, op)
#    6133 def _arith_method(self, other, op):
#    6134     self, other = self._align_for_op(other)
# -> 6135     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\base.py:1382, in IndexOpsMixin._arith_method(self, other, op)
#    1379     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1381 with np.errstate(all="ignore"):
# -> 1382     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1384 return self._construct_result(result, name=res_name)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:227, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)
#     225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
# --> 227         result = _masked_arith_op(left, right, op)
#     228     else:
#     229         raise
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:163, in _masked_arith_op(x, y, op)
#     161     # See GH#5284, GH#5035, GH#19448 for historical reference
#     162     if mask.any():
# --> 163         result[mask] = op(xrav[mask], yrav[mask])
#     165 else:
#     166     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39627 entries, 0 to 39626
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   39627 non-null  int64
#  1   listing_url          39627 non-null  object
#  2   name                 39627 non-null  object
#  3   picture_url          39627 non-null  object
#  4   latitude             39627 non-null  float64
#  5   longitude            39627 non-null  float64
#  6   property_type        39627 non-null  object
#  7   room_type            39627 non-null  object
#  8   accommodates         39627 non-null  int64
#  9   bathrooms_text       39627 non-null  object
#  10  bedrooms             39627 non-null  float64
#  11  beds                 39627 non-null  float64
#  12  amenities            39627 non-null  object
#  13  price                39627 non-null  object
#  14  minimum_nights       39627 non-null  int64
#  15  maximum_nights       39627 non-null  int64
#  16  availability_30      39627 non-null  int64
#  17  availability_365     39627 non-null  int64
#  18  neighbourhood_group  39627 non-null  object
#  19  neighbourhood        39627 non-null  object
# dtypes: float64(4), int64(6), object(10)
# memory usage: 6.0+ MB

# %%
print(df['price'].dtype)
# Out:
# object

# %%
# Since price has $, we need to remove it before converting it into a integer kind column
df['price'] = df['price'].replace({'\$':'',',':''},regex=True).astype(float)

# %%
df.head()
# Out:
#      id                        listing_url  \
# 0  2595  https://www.airbnb.com/rooms/2595
# 1  5121  https://www.airbnb.com/rooms/5121
# 2  6848  https://www.airbnb.com/rooms/6848
# 3  6990  https://www.airbnb.com/rooms/6990
# 4  6872  https://www.airbnb.com/rooms/6872
#
#                                                 name  \
# 0  Rental unit in New York · ★4.68 · Studio · 1 b...
# 1  Rental unit in Brooklyn · ★4.52 · 1 bedroom · ...
# 2  Rental unit in Brooklyn · ★4.58 · 2 bedrooms ·...
# 3  Rental unit in New York · ★4.88 · 1 bedroom · ...
# 4  Condo in New York · 1 bedroom · 1 bed · 1 shar...
#
#                                          picture_url  latitude  longitude  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...  40.75356  -73.98559
# 1  https://a0.muscache.com/pictures/2090980c-b68e...  40.68535  -73.95512
# 2  https://a0.muscache.com/pictures/e4f031a7-f146...  40.70935  -73.95342
# 3  https://a0.muscache.com/pictures/be6cd5b3-9295...  40.78778  -73.94759
# 4  https://a0.muscache.com/pictures/miso/Hosting-...  40.80107  -73.94255
#
#                  property_type        room_type  accommodates bathrooms_text  \
# 0           Entire rental unit  Entire home/apt             1         1 bath
# 1  Private room in rental unit     Private room             2        Unknown
# 2           Entire rental unit  Entire home/apt             3         1 bath
# 3  Private room in rental unit     Private room             1  1 shared bath
# 4        Private room in condo     Private room             1  1 shared bath
#
#    bedrooms  beds                                          amenities  price  \
# 0       1.0   1.0  ["Long term stays allowed", "Cooking basics", ...  240.0
# 1       1.0   1.0  ["Air conditioning", "Wifi", "Kitchen", "Heati...   66.0
# 2       2.0   1.0  ["Cooking basics", "Microwave", "Extra pillows...   81.0
# 3       1.0   1.0  ["Hair dryer", "Air conditioning", "Fire extin...   70.0
# 4       1.0   1.0  ["Fire extinguisher", "Long term stays allowed...   65.0
#
#    minimum_nights  maximum_nights  availability_30  availability_365  \
# 0              30            1125                4               339
# 1              30             730               30                88
# 2              30             730                0               142
# 3              30             365                0                93
# 4              30             180               24               359
#
#   neighbourhood_group       neighbourhood
# 0           Manhattan             Midtown
# 1            Brooklyn  Bedford-Stuyvesant
# 2            Brooklyn        Williamsburg
# 3           Manhattan         East Harlem
# 4           Manhattan         East Harlem

# %%
df['price_per_bedroom'] = df['price']/df['beds']

# %%
df.head(30)
# Out:
#        id                         listing_url  \
# 0    2595   https://www.airbnb.com/rooms/2595
# 1    5121   https://www.airbnb.com/rooms/5121
# 2    6848   https://www.airbnb.com/rooms/6848
# 3    6990   https://www.airbnb.com/rooms/6990
# 4    6872   https://www.airbnb.com/rooms/6872
# 5    7097   https://www.airbnb.com/rooms/7097
# 6    7064   https://www.airbnb.com/rooms/7064
# 7    7801   https://www.airbnb.com/rooms/7801
# 8    8490   https://www.airbnb.com/rooms/8490
# 9   10452  https://www.airbnb.com/rooms/10452
# 10   9357   https://www.airbnb.com/rooms/9357
# 11  12192  https://www.airbnb.com/rooms/12192
# 12  11943  https://www.airbnb.com/rooms/11943
# 13  12937  https://www.airbnb.com/rooms/12937
# 14  13808  https://www.airbnb.com/rooms/13808
# 15  12940  https://www.airbnb.com/rooms/12940
# 16  14434  https://www.airbnb.com/rooms/14434
# 17  14314  https://www.airbnb.com/rooms/14314
# 18  15385  https://www.airbnb.com/rooms/15385
# 19  15396  https://www.airbnb.com/rooms/15396
# 20  15341  https://www.airbnb.com/rooms/15341
# 21  16580  https://www.airbnb.com/rooms/16580
# 22  16338  https://www.airbnb.com/rooms/16338
# 23  16974  https://www.airbnb.com/rooms/16974
# 24  16821  https://www.airbnb.com/rooms/16821
# 25  17037  https://www.airbnb.com/rooms/17037
# 26  18198  https://www.airbnb.com/rooms/18198
# 27  18728  https://www.airbnb.com/rooms/18728
# 28  18152  https://www.airbnb.com/rooms/18152
# 29  18961  https://www.airbnb.com/rooms/18961
#
#                                                  name  \
# 0   Rental unit in New York · ★4.68 · Studio · 1 b...
# 1   Rental unit in Brooklyn · ★4.52 · 1 bedroom · ...
# 2   Rental unit in Brooklyn · ★4.58 · 2 bedrooms ·...
# 3   Rental unit in New York · ★4.88 · 1 bedroom · ...
# 4   Condo in New York · 1 bedroom · 1 bed · 1 shar...
# 5   Home in Brooklyn · ★4.88 · 1 bedroom · 2 beds ...
# 6   Loft in Brooklyn · ★4.91 · 1 bedroom · 1 bed ·...
# 7   Place to stay in Brooklyn · ★4.90 · 1 bed · 1 ...
# 8   Loft in Brooklyn · ★4.77 · 1 bedroom · 4 beds ...
# 9   Rental unit in Brooklyn · ★4.65 · 1 bedroom · ...
# 10  Rental unit in New York · ★4.52 · Studio · 1 b...
# 11  Rental unit in New York · ★4.39 · 1 bedroom · ...
# 12     Home in Brooklyn · 1 bedroom · 2 beds · 1 bath
# 13  Townhouse in Queens · ★4.91 · 1 bedroom · 1 be...
# 14  Townhouse in Brooklyn · ★4.65 · 1 bedroom · 1 ...
# 15  Rental unit in Brooklyn · ★4.52 · 1 bedroom · ...
# 16  Rental unit in Brooklyn · ★4.56 · 1 bedroom · ...
# 17  Rental unit in Brooklyn · ★4.82 · 1 bedroom · ...
# 18  Rental unit in Brooklyn · ★4.87 · 1 bedroom · ...
# 19  Rental unit in New York · ★5.0 · 2 bedrooms · ...
# 20  Condo in New York · ★4.56 · 1 bedroom · 2 beds...
# 21  Condo in New York · ★4.79 · 1 bedroom · 1 bed ...
# 22  Rental unit in Brooklyn · ★4.64 · 1 bedroom · ...
# 23  Loft in New York · ★4.85 · 4 bedrooms · 6 beds...
# 24  Rental unit in New York · ★4.72 · 1 bedroom · ...
# 25  Rental unit in New York · ★4.80 · 1 bedroom · ...
# 26  Condo in Queens · ★5.0 · 1 bedroom · 1 bed · 1...
# 27  Loft in New York · ★4.95 · 1 bedroom · 1 bed ·...
# 28  Rental unit in New York · ★4.41 · 2 bedrooms ·...
# 29  Rental unit in New York · 1 bedroom · 1 bed · ...
#
#                                           picture_url   latitude  longitude  \
# 0   https://a0.muscache.com/pictures/miso/Hosting-...  40.753560 -73.985590
# 1   https://a0.muscache.com/pictures/2090980c-b68e...  40.685350 -73.955120
# 2   https://a0.muscache.com/pictures/e4f031a7-f146...  40.709350 -73.953420
# 3   https://a0.muscache.com/pictures/be6cd5b3-9295...  40.787780 -73.947590
# 4   https://a0.muscache.com/pictures/miso/Hosting-...  40.801070 -73.942550
# 5   https://a0.muscache.com/pictures/miso/Hosting-...  40.691940 -73.973890
# 6   https://a0.muscache.com/pictures/13708959/7e74...  40.712480 -73.958810
# 7   https://a0.muscache.com/pictures/miso/Hosting-...  40.718807 -73.956177
# 8   https://a0.muscache.com/pictures/1d0d9773-c829...  40.684620 -73.938390
# 9   https://a0.muscache.com/pictures/16336315/c4bf...  40.682940 -73.956820
# 10  https://a0.muscache.com/pictures/90036/4e60665...  40.767240 -73.986640
# 11  https://a0.muscache.com/pictures/miso/Hosting-...  40.722960 -73.983830
# 12  https://a0.muscache.com/pictures/53007/d30884b...  40.637020 -73.963270
# 13  https://a0.muscache.com/pictures/2053dcc6-7721...  40.747570 -73.945710
# 14  https://a0.muscache.com/pictures/81099/72ccf5f...  40.680640 -73.940390
# 15  https://a0.muscache.com/pictures/miso/Hosting-...  40.679460 -73.954170
# 16  https://a0.muscache.com/pictures/bb0ae649-d842...  40.687770 -73.949760
# 17  https://a0.muscache.com/pictures/26430342-31f8...  40.735350 -73.955840
# 18  https://a0.muscache.com/pictures/miso/Hosting-...  40.712110 -73.963970
# 19  https://a0.muscache.com/pictures/575128a1-08e7...  40.744930 -73.995210
# 20  https://a0.muscache.com/pictures/e81f29d3-9de3...  40.721359 -73.993668
# 21  https://a0.muscache.com/pictures/37e211bb-6ef8...  40.723727 -73.976259
# 22  https://a0.muscache.com/pictures/7768624/01114...  40.691210 -73.968040
# 23  https://a0.muscache.com/pictures/miso/Hosting-...  40.801900 -73.937620
# 24  https://a0.muscache.com/pictures/airflow/Hosti...  40.722810 -73.985010
# 25  https://a0.muscache.com/pictures/6477265/3746d...  40.722890 -73.980280
# 26  https://a0.muscache.com/pictures/3324483/1493e...  40.748840 -73.905360
# 27  https://a0.muscache.com/pictures/460797/618231...  40.742610 -74.003530
# 28  https://a0.muscache.com/pictures/2c371d89-e590...  40.769670 -73.948310
# 29  https://a0.muscache.com/pictures/412950/ff300c...  40.738080 -73.980010
#
#                   property_type        room_type  accommodates  \
# 0            Entire rental unit  Entire home/apt             1
# 1   Private room in rental unit     Private room             2
# 2            Entire rental unit  Entire home/apt             3
# 3   Private room in rental unit     Private room             1
# 4         Private room in condo     Private room             1
# 5          Private room in home     Private room             2
# 6          Private room in loft     Private room             2
# 7                  Entire place  Entire home/apt             2
# 8                   Entire loft  Entire home/apt             5
# 9   Private room in rental unit     Private room             2
# 10           Entire rental unit  Entire home/apt             2
# 11  Private room in rental unit     Private room             2
# 12         Private room in home     Private room             1
# 13    Private room in townhouse     Private room             3
# 14    Private room in townhouse     Private room             2
# 15           Entire rental unit  Entire home/apt             2
# 16  Private room in rental unit     Private room             2
# 17           Entire rental unit  Entire home/apt             2
# 18  Private room in rental unit     Private room             1
# 19           Entire rental unit  Entire home/apt             4
# 20                 Entire condo  Entire home/apt             3
# 21        Private room in condo     Private room             1
# 22  Private room in rental unit     Private room             1
# 23                  Entire loft  Entire home/apt             8
# 24  Private room in rental unit     Private room             1
# 25           Entire rental unit  Entire home/apt             2
# 26        Private room in condo     Private room             1
# 27         Private room in loft     Private room             3
# 28  Private room in rental unit     Private room             2
# 29  Private room in rental unit     Private room             2
#
#     bathrooms_text  ...  beds  \
# 0           1 bath  ...   1.0
# 1          Unknown  ...   1.0
# 2           1 bath  ...   1.0
# 3    1 shared bath  ...   1.0
# 4    1 shared bath  ...   1.0
# 5   1 private bath  ...   2.0
# 6    1 shared bath  ...   1.0
# 7           1 bath  ...   1.0
# 8           1 bath  ...   4.0
# 9    1 shared bath  ...   2.0
# 10          1 bath  ...   1.0
# 11   1 shared bath  ...   1.0
# 12          1 bath  ...   2.0
# 13  1 private bath  ...   1.0
# 14  1 private bath  ...   1.0
# 15          1 bath  ...   1.0
# 16   1 shared bath  ...   1.0
# 17          1 bath  ...   2.0
# 18   1 shared bath  ...   1.0
# 19         2 baths  ...   2.0
# 20          1 bath  ...   2.0
# 21   1 shared bath  ...   1.0
# 22   1 shared bath  ...   1.0
# 23         2 baths  ...   6.0
# 24   1 shared bath  ...   1.0
# 25          1 bath  ...   1.0
# 26   1 shared bath  ...   1.0
# 27       1.5 baths  ...   1.0
# 28   1 shared bath  ...   1.0
# 29          1 bath  ...   1.0
#
#                                             amenities  price  minimum_nights  \
# 0   ["Long term stays allowed", "Cooking basics", ...  240.0              30
# 1   ["Air conditioning", "Wifi", "Kitchen", "Heati...   66.0              30
# 2   ["Cooking basics", "Microwave", "Extra pillows...   81.0              30
# 3   ["Hair dryer", "Air conditioning", "Fire extin...   70.0              30
# 4   ["Fire extinguisher", "Long term stays allowed...   65.0              30
# 5   ["Outdoor dining area", "Long term stays allow...  205.0               2
# 6   ["Air conditioning", "Iron", "Heating", "Essen...   95.0              30
# 7   ["Long term stays allowed", "Stainless steel s...  350.0              30
# 8   ["Outdoor dining area", "Long term stays allow...  161.0              30
# 9   ["Long term stays allowed", "Coffee", "Cooking...   90.0              30
# 10  ["Long term stays allowed", "Paid washer \u201...  175.0              45
# 11  ["Long term stays allowed", "Cooking basics", ...   70.0              30
# 12  ["Air conditioning", "Heating", "Washer", "Dry...  150.0              30
# 13  ["Private backyard \u2013 Fully fenced", "Coff...  165.0              30
# 14  ["Long term stays allowed", "Coffee", "Books a...  111.0              30
# 15  ["Cooking basics", "Microwave", "Dishes and si...  120.0              30
# 16  ["Hair dryer", "Air conditioning", "Heating", ...   70.0              30
# 17  ["Long term stays allowed", "Coffee", "Cooking...  115.0              30
# 18  ["Air conditioning", "Heating", "Lock on bedro...   95.0              30
# 19  ["Outdoor dining area", "Cooking basics", "Pet...  400.0             120
# 20  ["Outdoor dining area", "Long term stays allow...  160.0              30
# 21  ["Backyard", "Cooking basics", "Microwave", "E...  163.0               1
# 22  ["Outdoor dining area", "Long term stays allow...   60.0              30
# 23  ["Cooking basics", "Microwave", "Elevator", "C...  300.0              30
# 24  ["Outdoor dining area", "Coffee", "Cooking bas...  199.0              30
# 25  ["Long term stays allowed", "Cooking basics", ...  220.0              30
# 26  ["Air conditioning", "Heating", "Washer", "Dry...   65.0              30
# 27  ["Coffee", "Cooking basics", "Microwave", "Ele...  133.0              30
# 28  ["Hair dryer", "Air conditioning", "Pool", "Mi...  500.0              30
# 29  ["Hair dryer", "Air conditioning", "Iron", "He...   95.0              30
#
#     maximum_nights  availability_30  availability_365  neighbourhood_group  \
# 0             1125                4               339            Manhattan
# 1              730               30                88             Brooklyn
# 2              730                0               142             Brooklyn
# 3              365                0                93            Manhattan
# 4              180               24               359            Manhattan
# 5             1125                5               276             Brooklyn
# 6               45                0                26             Brooklyn
# 7              120                2               257             Brooklyn
# 8             1125               30               365             Brooklyn
# 9              730                0               297             Brooklyn
# 10             365                2               327            Manhattan
# 11            1125                0                54            Manhattan
# 12             730                0                 0             Brooklyn
# 13              30               24               264               Queens
# 14            1125               20               143             Brooklyn
# 15             365                4               188             Brooklyn
# 16             730                0                 0             Brooklyn
# 17            1125                3               234             Brooklyn
# 18              30                0               183             Brooklyn
# 19             365                0                61            Manhattan
# 20            1125                3               153            Manhattan
# 21            1125                9               158            Manhattan
# 22             200               10               345             Brooklyn
# 23             365               21               261            Manhattan
# 24              31               28                28            Manhattan
# 25              90               28               177            Manhattan
# 26             365                0                59               Queens
# 27              60               26               347            Manhattan
# 28              30               30               365            Manhattan
# 29             180                0                 0            Manhattan
#
#          neighbourhood price_per_bedroom
# 0              Midtown            240.00
# 1   Bedford-Stuyvesant             66.00
# 2         Williamsburg             81.00
# 3          East Harlem             70.00
# 4          East Harlem             65.00
# 5          Fort Greene            102.50
# 6         Williamsburg             95.00
# 7         Williamsburg            350.00
# 8   Bedford-Stuyvesant             40.25
# 9   Bedford-Stuyvesant             45.00
# 10      Hell's Kitchen            175.00
# 11        East Village             70.00
# 12            Flatbush             75.00
# 13    Long Island City            165.00
# 14  Bedford-Stuyvesant            111.00
# 15  Bedford-Stuyvesant            120.00
# 16  Bedford-Stuyvesant             70.00
# 17          Greenpoint             57.50
# 18        Williamsburg             95.00
# 19             Chelsea            200.00
# 20     Lower East Side             80.00
# 21        East Village            163.00
# 22        Clinton Hill             60.00
# 23         East Harlem             50.00
# 24        East Village            199.00
# 25        East Village            220.00
# 26            Woodside             65.00
# 27             Chelsea            133.00
# 28     Upper East Side            500.00
# 29            Kips Bay             95.00
#
# [30 rows x 21 columns]

# %%
# Luxury vs budget listing
df['listing_category'] = df['price'].apply(lambda x:'Luxury' if x > 500.0 else 'Budget' if x < 100.0 else 'Standard')

# %%
df.head()
# Out:
#      id                        listing_url  \
# 0  2595  https://www.airbnb.com/rooms/2595
# 1  5121  https://www.airbnb.com/rooms/5121
# 2  6848  https://www.airbnb.com/rooms/6848
# 3  6990  https://www.airbnb.com/rooms/6990
# 4  6872  https://www.airbnb.com/rooms/6872
#
#                                                 name  \
# 0  Rental unit in New York · ★4.68 · Studio · 1 b...
# 1  Rental unit in Brooklyn · ★4.52 · 1 bedroom · ...
# 2  Rental unit in Brooklyn · ★4.58 · 2 bedrooms ·...
# 3  Rental unit in New York · ★4.88 · 1 bedroom · ...
# 4  Condo in New York · 1 bedroom · 1 bed · 1 shar...
#
#                                          picture_url  latitude  longitude  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...  40.75356  -73.98559
# 1  https://a0.muscache.com/pictures/2090980c-b68e...  40.68535  -73.95512
# 2  https://a0.muscache.com/pictures/e4f031a7-f146...  40.70935  -73.95342
# 3  https://a0.muscache.com/pictures/be6cd5b3-9295...  40.78778  -73.94759
# 4  https://a0.muscache.com/pictures/miso/Hosting-...  40.80107  -73.94255
#
#                  property_type        room_type  accommodates bathrooms_text  \
# 0           Entire rental unit  Entire home/apt             1         1 bath
# 1  Private room in rental unit     Private room             2        Unknown
# 2           Entire rental unit  Entire home/apt             3         1 bath
# 3  Private room in rental unit     Private room             1  1 shared bath
# 4        Private room in condo     Private room             1  1 shared bath
#
#    ...                                          amenities  price  \
# 0  ...  ["Long term stays allowed", "Cooking basics", ...  240.0
# 1  ...  ["Air conditioning", "Wifi", "Kitchen", "Heati...   66.0
# 2  ...  ["Cooking basics", "Microwave", "Extra pillows...   81.0
# 3  ...  ["Hair dryer", "Air conditioning", "Fire extin...   70.0
# 4  ...  ["Fire extinguisher", "Long term stays allowed...   65.0
#
#   minimum_nights  maximum_nights  availability_30  availability_365  \
# 0             30            1125                4               339
# 1             30             730               30                88
# 2             30             730                0               142
# 3             30             365                0                93
# 4             30             180               24               359
#
#    neighbourhood_group       neighbourhood price_per_bedroom listing_category
# 0            Manhattan             Midtown             240.0         Standard
# 1             Brooklyn  Bedford-Stuyvesant              66.0           Budget
# 2             Brooklyn        Williamsburg              81.0           Budget
# 3            Manhattan         East Harlem              70.0           Budget
# 4            Manhattan         East Harlem              65.0           Budget
#
# [5 rows x 22 columns]

# %%
print(df['listing_category'].value_counts())
# Out:
# listing_category
# Standard    22610
# Budget      14631
# Luxury       2386
# Name: count, dtype: int64

# %%
df['price_per_bed'] = df.apply(lambda row: row['price'] / row['beds'] 
                               if row['beds'] > 0 else row['price'], axis=1)

# %%
df.head()
# Out:
#      id                        listing_url  \
# 0  2595  https://www.airbnb.com/rooms/2595
# 1  5121  https://www.airbnb.com/rooms/5121
# 2  6848  https://www.airbnb.com/rooms/6848
# 3  6990  https://www.airbnb.com/rooms/6990
# 4  6872  https://www.airbnb.com/rooms/6872
#
#                                                 name  \
# 0  Rental unit in New York · ★4.68 · Studio · 1 b...
# 1  Rental unit in Brooklyn · ★4.52 · 1 bedroom · ...
# 2  Rental unit in Brooklyn · ★4.58 · 2 bedrooms ·...
# 3  Rental unit in New York · ★4.88 · 1 bedroom · ...
# 4  Condo in New York · 1 bedroom · 1 bed · 1 shar...
#
#                                          picture_url  latitude  longitude  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...  40.75356  -73.98559
# 1  https://a0.muscache.com/pictures/2090980c-b68e...  40.68535  -73.95512
# 2  https://a0.muscache.com/pictures/e4f031a7-f146...  40.70935  -73.95342
# 3  https://a0.muscache.com/pictures/be6cd5b3-9295...  40.78778  -73.94759
# 4  https://a0.muscache.com/pictures/miso/Hosting-...  40.80107  -73.94255
#
#                  property_type        room_type  accommodates bathrooms_text  \
# 0           Entire rental unit  Entire home/apt             1         1 bath
# 1  Private room in rental unit     Private room             2        Unknown
# 2           Entire rental unit  Entire home/apt             3         1 bath
# 3  Private room in rental unit     Private room             1  1 shared bath
# 4        Private room in condo     Private room             1  1 shared bath
#
#    ...  price  minimum_nights maximum_nights  availability_30  \
# 0  ...  240.0              30           1125                4
# 1  ...   66.0              30            730               30
# 2  ...   81.0              30            730                0
# 3  ...   70.0              30            365                0
# 4  ...   65.0              30            180               24
#
#    availability_365  neighbourhood_group       neighbourhood  \
# 0               339            Manhattan             Midtown
# 1                88             Brooklyn  Bedford-Stuyvesant
# 2               142             Brooklyn        Williamsburg
# 3                93            Manhattan         East Harlem
# 4               359            Manhattan         East Harlem
#
#    price_per_bedroom listing_category price_per_bed
# 0              240.0         Standard         240.0
# 1               66.0           Budget          66.0
# 2               81.0           Budget          81.0
# 3               70.0           Budget          70.0
# 4               65.0           Budget          65.0
#
# [5 rows x 23 columns]

# %%
df['price_per_accomodate'] = df.apply(lambda row:row['price']/row['accommodates'] if row['accommodates'] > 0 else row['price'],axis = 1)

# %%
df.head()
# Out:
#      id                        listing_url  \
# 0  2595  https://www.airbnb.com/rooms/2595
# 1  5121  https://www.airbnb.com/rooms/5121
# 2  6848  https://www.airbnb.com/rooms/6848
# 3  6990  https://www.airbnb.com/rooms/6990
# 4  6872  https://www.airbnb.com/rooms/6872
#
#                                                 name  \
# 0  Rental unit in New York · ★4.68 · Studio · 1 b...
# 1  Rental unit in Brooklyn · ★4.52 · 1 bedroom · ...
# 2  Rental unit in Brooklyn · ★4.58 · 2 bedrooms ·...
# 3  Rental unit in New York · ★4.88 · 1 bedroom · ...
# 4  Condo in New York · 1 bedroom · 1 bed · 1 shar...
#
#                                          picture_url  latitude  longitude  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...  40.75356  -73.98559
# 1  https://a0.muscache.com/pictures/2090980c-b68e...  40.68535  -73.95512
# 2  https://a0.muscache.com/pictures/e4f031a7-f146...  40.70935  -73.95342
# 3  https://a0.muscache.com/pictures/be6cd5b3-9295...  40.78778  -73.94759
# 4  https://a0.muscache.com/pictures/miso/Hosting-...  40.80107  -73.94255
#
#                  property_type        room_type  accommodates bathrooms_text  \
# 0           Entire rental unit  Entire home/apt             1         1 bath
# 1  Private room in rental unit     Private room             2        Unknown
# 2           Entire rental unit  Entire home/apt             3         1 bath
# 3  Private room in rental unit     Private room             1  1 shared bath
# 4        Private room in condo     Private room             1  1 shared bath
#
#    ...  minimum_nights  maximum_nights availability_30  availability_365  \
# 0  ...              30            1125               4               339
# 1  ...              30             730              30                88
# 2  ...              30             730               0               142
# 3  ...              30             365               0                93
# 4  ...              30             180              24               359
#
#    neighbourhood_group       neighbourhood  price_per_bedroom  \
# 0            Manhattan             Midtown              240.0
# 1             Brooklyn  Bedford-Stuyvesant               66.0
# 2             Brooklyn        Williamsburg               81.0
# 3            Manhattan         East Harlem               70.0
# 4            Manhattan         East Harlem               65.0
#
#    listing_category price_per_bed price_per_accomodate
# 0          Standard         240.0                240.0
# 1            Budget          66.0                 33.0
# 2            Budget          81.0                 27.0
# 3            Budget          70.0                 70.0
# 4            Budget          65.0                 65.0
#
# [5 rows x 24 columns]

# %%
df['availability_rate'] = round((df['availability_365']/365)*100,2)

# %%
df.head()
# Out:
#      id                        listing_url  \
# 0  2595  https://www.airbnb.com/rooms/2595
# 1  5121  https://www.airbnb.com/rooms/5121
# 2  6848  https://www.airbnb.com/rooms/6848
# 3  6990  https://www.airbnb.com/rooms/6990
# 4  6872  https://www.airbnb.com/rooms/6872
#
#                                                 name  \
# 0  Rental unit in New York · ★4.68 · Studio · 1 b...
# 1  Rental unit in Brooklyn · ★4.52 · 1 bedroom · ...
# 2  Rental unit in Brooklyn · ★4.58 · 2 bedrooms ·...
# 3  Rental unit in New York · ★4.88 · 1 bedroom · ...
# 4  Condo in New York · 1 bedroom · 1 bed · 1 shar...
#
#                                          picture_url  latitude  longitude  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...  40.75356  -73.98559
# 1  https://a0.muscache.com/pictures/2090980c-b68e...  40.68535  -73.95512
# 2  https://a0.muscache.com/pictures/e4f031a7-f146...  40.70935  -73.95342
# 3  https://a0.muscache.com/pictures/be6cd5b3-9295...  40.78778  -73.94759
# 4  https://a0.muscache.com/pictures/miso/Hosting-...  40.80107  -73.94255
#
#                  property_type        room_type  accommodates bathrooms_text  \
# 0           Entire rental unit  Entire home/apt             1         1 bath
# 1  Private room in rental unit     Private room             2        Unknown
# 2           Entire rental unit  Entire home/apt             3         1 bath
# 3  Private room in rental unit     Private room             1  1 shared bath
# 4        Private room in condo     Private room             1  1 shared bath
#
#    ...  maximum_nights  availability_30 availability_365  neighbourhood_group  \
# 0  ...            1125                4              339            Manhattan
# 1  ...             730               30               88             Brooklyn
# 2  ...             730                0              142             Brooklyn
# 3  ...             365                0               93            Manhattan
# 4  ...             180               24              359            Manhattan
#
#         neighbourhood  price_per_bedroom  listing_category  price_per_bed  \
# 0             Midtown              240.0          Standard          240.0
# 1  Bedford-Stuyvesant               66.0            Budget           66.0
# 2        Williamsburg               81.0            Budget           81.0
# 3         East Harlem               70.0            Budget           70.0
# 4         East Harlem               65.0            Budget           65.0
#
#   price_per_accomodate availability_rate
# 0                240.0             92.88
# 1                 33.0             24.11
# 2                 27.0             38.90
# 3                 70.0             25.48
# 4                 65.0             98.36
#
# [5 rows x 25 columns]

# %%
df['num_amenities'] = df['amenities'].apply(lambda x: len(x.split(',')) if pd.notnull(x) else 0)

# %%
df.head()
# Out:
#      id                        listing_url  \
# 0  2595  https://www.airbnb.com/rooms/2595
# 1  5121  https://www.airbnb.com/rooms/5121
# 2  6848  https://www.airbnb.com/rooms/6848
# 3  6990  https://www.airbnb.com/rooms/6990
# 4  6872  https://www.airbnb.com/rooms/6872
#
#                                                 name  \
# 0  Rental unit in New York · ★4.68 · Studio · 1 b...
# 1  Rental unit in Brooklyn · ★4.52 · 1 bedroom · ...
# 2  Rental unit in Brooklyn · ★4.58 · 2 bedrooms ·...
# 3  Rental unit in New York · ★4.88 · 1 bedroom · ...
# 4  Condo in New York · 1 bedroom · 1 bed · 1 shar...
#
#                                          picture_url  latitude  longitude  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...  40.75356  -73.98559
# 1  https://a0.muscache.com/pictures/2090980c-b68e...  40.68535  -73.95512
# 2  https://a0.muscache.com/pictures/e4f031a7-f146...  40.70935  -73.95342
# 3  https://a0.muscache.com/pictures/be6cd5b3-9295...  40.78778  -73.94759
# 4  https://a0.muscache.com/pictures/miso/Hosting-...  40.80107  -73.94255
#
#                  property_type        room_type  accommodates bathrooms_text  \
# 0           Entire rental unit  Entire home/apt             1         1 bath
# 1  Private room in rental unit     Private room             2        Unknown
# 2           Entire rental unit  Entire home/apt             3         1 bath
# 3  Private room in rental unit     Private room             1  1 shared bath
# 4        Private room in condo     Private room             1  1 shared bath
#
#    ...  availability_30  availability_365 neighbourhood_group  \
# 0  ...                4               339           Manhattan
# 1  ...               30                88            Brooklyn
# 2  ...                0               142            Brooklyn
# 3  ...                0                93           Manhattan
# 4  ...               24               359           Manhattan
#
#         neighbourhood  price_per_bedroom  listing_category  price_per_bed  \
# 0             Midtown              240.0          Standard          240.0
# 1  Bedford-Stuyvesant               66.0            Budget           66.0
# 2        Williamsburg               81.0            Budget           81.0
# 3         East Harlem               70.0            Budget           70.0
# 4         East Harlem               65.0            Budget           65.0
#
#    price_per_accomodate availability_rate num_amenities
# 0                 240.0             92.88            32
# 1                  33.0             24.11             4
# 2                  27.0             38.90            26
# 3                  70.0             25.48            19
# 4                  65.0             98.36            18
#
# [5 rows x 26 columns]

# %%
df['bedroom_to_accommodate_ratio'] = df['bedrooms'] / df['accommodates']

# %%
df.head()
# Out:
#      id                        listing_url  \
# 0  2595  https://www.airbnb.com/rooms/2595
# 1  5121  https://www.airbnb.com/rooms/5121
# 2  6848  https://www.airbnb.com/rooms/6848
# 3  6990  https://www.airbnb.com/rooms/6990
# 4  6872  https://www.airbnb.com/rooms/6872
#
#                                                 name  \
# 0  Rental unit in New York · ★4.68 · Studio · 1 b...
# 1  Rental unit in Brooklyn · ★4.52 · 1 bedroom · ...
# 2  Rental unit in Brooklyn · ★4.58 · 2 bedrooms ·...
# 3  Rental unit in New York · ★4.88 · 1 bedroom · ...
# 4  Condo in New York · 1 bedroom · 1 bed · 1 shar...
#
#                                          picture_url  latitude  longitude  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...  40.75356  -73.98559
# 1  https://a0.muscache.com/pictures/2090980c-b68e...  40.68535  -73.95512
# 2  https://a0.muscache.com/pictures/e4f031a7-f146...  40.70935  -73.95342
# 3  https://a0.muscache.com/pictures/be6cd5b3-9295...  40.78778  -73.94759
# 4  https://a0.muscache.com/pictures/miso/Hosting-...  40.80107  -73.94255
#
#                  property_type        room_type  accommodates bathrooms_text  \
# 0           Entire rental unit  Entire home/apt             1         1 bath
# 1  Private room in rental unit     Private room             2        Unknown
# 2           Entire rental unit  Entire home/apt             3         1 bath
# 3  Private room in rental unit     Private room             1  1 shared bath
# 4        Private room in condo     Private room             1  1 shared bath
#
#    ...  availability_365  neighbourhood_group       neighbourhood  \
# 0  ...               339            Manhattan             Midtown
# 1  ...                88             Brooklyn  Bedford-Stuyvesant
# 2  ...               142             Brooklyn        Williamsburg
# 3  ...                93            Manhattan         East Harlem
# 4  ...               359            Manhattan         East Harlem
#
#    price_per_bedroom  listing_category  price_per_bed  price_per_accomodate  \
# 0              240.0          Standard          240.0                 240.0
# 1               66.0            Budget           66.0                  33.0
# 2               81.0            Budget           81.0                  27.0
# 3               70.0            Budget           70.0                  70.0
# 4               65.0            Budget           65.0                  65.0
#
#    availability_rate num_amenities bedroom_to_accommodate_ratio
# 0              92.88            32                     1.000000
# 1              24.11             4                     0.500000
# 2              38.90            26                     0.666667
# 3              25.48            19                     1.000000
# 4              98.36            18                     1.000000
#
# [5 rows x 27 columns]

# %%
print(df['price'].describe())
# Out:
# count    39627.000000
# mean       208.816464
# std        482.380712
# min          8.000000
# 25%         75.000000
# 50%        127.000000
# 75%        214.000000
# max      30000.000000
# Name: price, dtype: float64

# %%
# Price distribution
plt.figure(figsize=(8, 5))
sns.histplot(df['price'], bins=50, kde=True, color='blue', edgecolor='black')
plt.title("Distribution of Airbnb Prices")
plt.xlabel("Price ($)")
plt.ylabel("Count")
Q3 = df['price'].quantile(0.75)
IQR = Q3 - df['price'].quantile(0.25)
upper_limit = Q3 + 1.5 * IQR  # Remove extreme outliers

plt.xlim(0, upper_limit)  # Adjust based on data
plt.show()
