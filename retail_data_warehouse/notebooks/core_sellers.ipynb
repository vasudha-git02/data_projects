# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as f
import os

# %%
base_path = r"C:\Users\vasudha.tanniru\Documents\GitHub\data_projects\retail_data_warehouse\warehouse"
staging_path = os.path.join(base_path,"staging")
core_path = os.path.join(base_path,"core")

# %%
spark = SparkSession.builder.appName("Create Core Sellers").getOrCreate()

# %%
sellers_df = spark.read.parquet(os.path.join(staging_path,"sellers"))

# %%
sellers_df.show()
# Out:
# +--------------------+----------------------+--------------------+------------+
# |           seller_id|seller_zip_code_prefix|         seller_city|seller_state|
# +--------------------+----------------------+--------------------+------------+
# |f6122bc84774df1b3...|                  6436|             barueri|          SP|
# |8132b9bd16876e1b0...|                 88058|       florianopolis|          SC|
# |a254c682cc01e119f...|                 16500|          cafelandia|          SP|
# |cb9fb4ca75d7ba843...|                  3551|           sao paulo|          SP|
# |c5ebe6598748b0aea...|                 95910|             lajeado|          RS|
# |bd15ee794d5e640d9...|                 14078|      ribeirao preto|          SP|
# |7994b065a7ffb14e7...|                 29142|      cariacica / es|          ES|
# |67883baaae6134ee8...|                  1310|           sao paulo|          SP|
# |f52c2422904463fdd...|                  9230|santo andre/sao p...|          SP|
# |528bcf6680c36dddf...|                  3178|           sao paulo|          SP|
# |ea3ebea5317b0efbc...|                 88036|       florianopolis|          SC|
# |a218df5c097b0ca40...|                 14806|          araraquara|          SP|
# |f08a5b9dd67671296...|                 90230|        porto alegre|          RS|
# |13511db12ac61e2f8...|                 95020|       caxias do sul|          RS|
# |30a2f535bb48308f9...|                 13457|santa barbara d'o...|          SP|
# |83c8aafbefb034674...|                 85601|   francisco beltrao|          PR|
# |7e26c750b4cb9f676...|                 30270|      belo horizonte|          MG|
# |f3055483058c84d75...|                 40368|            salvador|          BA|
# |c458e2045a8aa8964...|                  9572|  sao caetano do sul|          SP|
# |ccb83a794700270fd...|                 88960|             sombrio|          SC|
# +--------------------+----------------------+--------------------+------------+
# only showing top 20 rows

# %%
print("Before dedup:",sellers_df.count(),"After:",sellers_df.dropDuplicates().count())
# Out:
# Before dedup: 3095 After: 3095

# %%
sellers_df.select(
    [f.count(f.when(f.col(c).isNull(), c)).alias(c) for c in sellers_df.columns]
).show()
# Out:
# +---------+----------------------+-----------+------------+
# |seller_id|seller_zip_code_prefix|seller_city|seller_state|
# +---------+----------------------+-----------+------------+
# |        0|                     0|          0|           0|
# +---------+----------------------+-----------+------------+

# %%
sellers_df.groupBy("seller_id").count().filter("count>1").show()
# Out:
# +---------+-----+
# |seller_id|count|
# +---------+-----+
# +---------+-----+

# %%
geolocation_summary_df = spark.read.parquet(os.path.join(core_path,"core_geolocation"))

# %%
core_sellers_df = (
                    sellers_df.join(
                      geolocation_summary_df, sellers_df.seller_zip_code_prefix == geolocation_summary_df.geolocation_zip_code_prefix,"left"
                    )
)

# %%
core_sellers_df.show()
# Out:
# +--------------------+----------------------+--------------------+------------+---------------------------+--------------------+-----------------+-------------------+-------------------+
# |           seller_id|seller_zip_code_prefix|         seller_city|seller_state|geolocation_zip_code_prefix|    geolocation_city|geolocation_state|avg_geolocation_lat|avg_geolocation_lng|
# +--------------------+----------------------+--------------------+------------+---------------------------+--------------------+-----------------+-------------------+-------------------+
# |f6122bc84774df1b3...|                  6436|             barueri|          SP|                       6436|             barueri|               sp|-23.537663121440325|-46.888915425858364|
# |8132b9bd16876e1b0...|                 88058|       florianopolis|          SC|                      88058|florian&oacute;polis|               sc|-27.450674474897465| -48.40169285789716|
# |8132b9bd16876e1b0...|                 88058|       florianopolis|          SC|                      88058|       florianopolis|               sc|-27.443540770120254| -48.40172378655695|
# |a254c682cc01e119f...|                 16500|          cafelandia|          SP|                      16500|          cafelandia|               sp|-21.802644003752377|-49.601912207398165|
# |cb9fb4ca75d7ba843...|                  3551|           sao paulo|          SP|                       3551|           sao paulo|               sp|-23.533192227708618|-46.503515518124125|
# |c5ebe6598748b0aea...|                 95910|             lajeado|          RS|                      95910|             lajeado|               rs|-29.430823732155332| -51.99377718667392|
# |bd15ee794d5e640d9...|                 14078|      ribeirao preto|          SP|                      14078|      ribeirao preto|               sp|-21.140737794465792| -47.76672134129578|
# |7994b065a7ffb14e7...|                 29142|      cariacica / es|          ES|                      29142|           cariacica|               es|-20.362939997151646| -40.37490496796692|
# |67883baaae6134ee8...|                  1310|           sao paulo|          SP|                       1310|           sao paulo|               sp| -23.56132994321025| -46.65638465454748|
# |f52c2422904463fdd...|                  9230|santo andre/sao p...|          SP|                       9230|         santo andre|               sp| -23.62122895658325| -46.52726700772707|
# |528bcf6680c36dddf...|                  3178|           sao paulo|          SP|                       3178|           sao paulo|               sp|-23.553632691405543|  -46.5882707131325|
# |ea3ebea5317b0efbc...|                 88036|       florianopolis|          SC|                      88036|       florianopolis|               sc| -27.58922628705614| -48.52283750224416|
# |a218df5c097b0ca40...|                 14806|          araraquara|          SP|                      14806|          araraquara|               sp| -21.75006081110468| -48.15766122149862|
# |f08a5b9dd67671296...|                 90230|        porto alegre|          RS|                      90230|        porto alegre|               rs|-30.008301633577542| -51.20140475549244|
# |13511db12ac61e2f8...|                 95020|       caxias do sul|          RS|                      95020|       caxias do sul|               rs|-29.165936335665876| -51.17895745543359|
# |30a2f535bb48308f9...|                 13457|santa barbara d'o...|          SP|                      13457|santa barbara doeste|               sp|-22.769423139337174| -47.37972522651845|
# |30a2f535bb48308f9...|                 13457|santa barbara d'o...|          SP|                      13457|santa barbara d'o...|               sp|-22.767230242987488|-47.385683697743474|
# |30a2f535bb48308f9...|                 13457|santa barbara d'o...|          SP|                      13457|santa barbara d o...|               sp|-22.768969106494186| -47.38556980919012|
# |83c8aafbefb034674...|                 85601|   francisco beltrao|          PR|                      85601|   francisco beltrao|               pr|-26.080457158205206| -53.05380797671792|
# |7e26c750b4cb9f676...|                 30270|      belo horizonte|          MG|                      30270|      belo horizonte|               mg|-19.921375589837062| -43.90611074343839|
# +--------------------+----------------------+--------------------+------------+---------------------------+--------------------+-----------------+-------------------+-------------------+
# only showing top 20 rows

# %%
core_sellers_df = (
    core_sellers_df
    .withColumn(
        "seller_city",
        f.when(f.col("seller_city").isNull(), f.col("geolocation_city"))
         .otherwise(f.col("seller_city"))
    )
    .withColumn(
        "seller_state",
        f.when(f.col("seller_state").isNull(), f.col("geolocation_state"))
         .otherwise(f.col("seller_state"))
    )
)

# %%
core_sellers_df.show()
# Out:
# +--------------------+----------------------+--------------------+------------+---------------------------+--------------------+-----------------+-------------------+-------------------+
# |           seller_id|seller_zip_code_prefix|         seller_city|seller_state|geolocation_zip_code_prefix|    geolocation_city|geolocation_state|avg_geolocation_lat|avg_geolocation_lng|
# +--------------------+----------------------+--------------------+------------+---------------------------+--------------------+-----------------+-------------------+-------------------+
# |f6122bc84774df1b3...|                  6436|             barueri|          SP|                       6436|             barueri|               sp|-23.537663121440325|-46.888915425858364|
# |8132b9bd16876e1b0...|                 88058|       florianopolis|          SC|                      88058|florian&oacute;polis|               sc|-27.450674474897465| -48.40169285789716|
# |8132b9bd16876e1b0...|                 88058|       florianopolis|          SC|                      88058|       florianopolis|               sc|-27.443540770120254| -48.40172378655695|
# |a254c682cc01e119f...|                 16500|          cafelandia|          SP|                      16500|          cafelandia|               sp|-21.802644003752377|-49.601912207398165|
# |cb9fb4ca75d7ba843...|                  3551|           sao paulo|          SP|                       3551|           sao paulo|               sp|-23.533192227708618|-46.503515518124125|
# |c5ebe6598748b0aea...|                 95910|             lajeado|          RS|                      95910|             lajeado|               rs|-29.430823732155332| -51.99377718667392|
# |bd15ee794d5e640d9...|                 14078|      ribeirao preto|          SP|                      14078|      ribeirao preto|               sp|-21.140737794465792| -47.76672134129578|
# |7994b065a7ffb14e7...|                 29142|      cariacica / es|          ES|                      29142|           cariacica|               es|-20.362939997151646| -40.37490496796692|
# |67883baaae6134ee8...|                  1310|           sao paulo|          SP|                       1310|           sao paulo|               sp| -23.56132994321025| -46.65638465454748|
# |f52c2422904463fdd...|                  9230|santo andre/sao p...|          SP|                       9230|         santo andre|               sp| -23.62122895658325| -46.52726700772707|
# |528bcf6680c36dddf...|                  3178|           sao paulo|          SP|                       3178|           sao paulo|               sp|-23.553632691405543|  -46.5882707131325|
# |ea3ebea5317b0efbc...|                 88036|       florianopolis|          SC|                      88036|       florianopolis|               sc| -27.58922628705614| -48.52283750224416|
# |a218df5c097b0ca40...|                 14806|          araraquara|          SP|                      14806|          araraquara|               sp| -21.75006081110468| -48.15766122149862|
# |f08a5b9dd67671296...|                 90230|        porto alegre|          RS|                      90230|        porto alegre|               rs|-30.008301633577542| -51.20140475549244|
# |13511db12ac61e2f8...|                 95020|       caxias do sul|          RS|                      95020|       caxias do sul|               rs|-29.165936335665876| -51.17895745543359|
# |30a2f535bb48308f9...|                 13457|santa barbara d'o...|          SP|                      13457|santa barbara doeste|               sp|-22.769423139337174| -47.37972522651845|
# |30a2f535bb48308f9...|                 13457|santa barbara d'o...|          SP|                      13457|santa barbara d'o...|               sp|-22.767230242987488|-47.385683697743474|
# |30a2f535bb48308f9...|                 13457|santa barbara d'o...|          SP|                      13457|santa barbara d o...|               sp|-22.768969106494186| -47.38556980919012|
# |83c8aafbefb034674...|                 85601|   francisco beltrao|          PR|                      85601|   francisco beltrao|               pr|-26.080457158205206| -53.05380797671792|
# |7e26c750b4cb9f676...|                 30270|      belo horizonte|          MG|                      30270|      belo horizonte|               mg|-19.921375589837062| -43.90611074343839|
# +--------------------+----------------------+--------------------+------------+---------------------------+--------------------+-----------------+-------------------+-------------------+
# only showing top 20 rows

# %%
core_sellers_df = (
    core_sellers_df
    .withColumn("avg_lat", f.col("avg_geolocation_lat"))
    .withColumn("avg_lng", f.col("avg_geolocation_lng"))
)

# %%
core_sellers_df = core_sellers_df.drop(
    "geolocation_zip_code_prefix",
    "geolocation_city",
    "geolocation_state",
    "avg_geolocation_lat",
    "avg_geolocation_lng"
)

# %%
core_sellers_df.coalesce(1).write.mode("overwrite").parquet(
    r"C:\Users\vasudha.tanniru\Documents\GitHub\data_projects\retail_data_warehouse\warehouse\core\core_sellers"
)
